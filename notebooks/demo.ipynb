# %% [markdown]
# # Regime-Adaptive Portfolio Optimizer — End-to-End Demo
#
# Skeleton notebook. Fill in at the Week 6 integration checkpoint once M1–M4 are merged.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from src.data_loader import get_prices, get_features, get_returns
from src.optimizer import solve_portfolio

# %%
prices = get_prices()
features = get_features()
returns = get_returns()
print(prices.shape, features.shape, returns.shape)
prices.tail()
